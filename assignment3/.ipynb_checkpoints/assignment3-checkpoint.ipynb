# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import (GradientBoostingClassifier as GBR, RandomForestClassifier as RF)

from sklearn.metrics import accuracy_score, classification_report
from ISLP import load_data
from ISLP.models import ModelSpec as MS, Stepwise, sklearn_selected

STATE = 161

# %%
# read data table
df = pd.read_table("./magic04.data", sep=',', header=None)

# %% [markdown]
# ## a. Scale and center df and split into train/test

# %%
# scale + center numerical columns
scaler = StandardScaler()

cols = df.select_dtypes(include=['float64']).columns
df[cols] = scaler.fit_transform(df[cols])

# %%
# split into train/test
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1:], test_size=0.2, random_state=STATE)

# Convert y_train and y_test to 1D arrays
flat_y_train = y_train.values.ravel()
flat_y_test = y_test.values.ravel()

# transform response to numeric values
le = LabelEncoder()

y_train_encoded = le.fit_transform(flat_y_train)
y_test_encoded = le.transform(flat_y_test)

# %% [markdown]
# ## b. Train models on training data & cross validate

# %%
# Logistic regression
params = {'C': [0.01, 0.1, 1, 10]}
lr = GridSearchCV(LogisticRegression(max_iter=1000), params, cv=5).fit(X_train, y_train_encoded)

best_lr = lr.best_estimator_

# %%
# Linear Discriminant Analysis
lda = LinearDiscriminantAnalysis().fit(X_train, y_train_encoded)

print(f"Accuracy: {lda.score(X_test, y_train_encoded):.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Linear Discriminant Analysis
#       2 lda = LinearDiscriminantAnalysis().fit(X_train, y_train_encoded)
# ----> 4 print(f"Accuracy: {lda.score(X_test, y_train_encoded):.4f}")
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/base.py:566, in ClassifierMixin.score(self, X, y, sample_weight)
#     541 """
#     542 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     543
#    (...)    562     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     563 """
#     564 from sklearn.metrics import accuracy_score
# --> 566 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:411, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     409 # Compute accuracy for each possible representation
#     410 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 411 y_type, y_true, y_pred, sample_weight = _check_targets(
#     412     y_true, y_pred, sample_weight
#     413 )
#     415 if y_type.startswith("multilabel"):
#     416     differing_labels = _count_nonzero(y_true - y_pred, xp=xp, device=device, axis=1)
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:108, in _check_targets(y_true, y_pred, sample_weight)
#      77 """Check that y_true and y_pred belong to the same classification task.
#      78
#      79 This converts multiclass or binary types to a common shape, and raises a
#    (...)    105 sample_weight : array or None
#     106 """
#     107 xp, _ = get_namespace(y_true, y_pred, sample_weight)
# --> 108 check_consistent_length(y_true, y_pred, sample_weight)
#     109 type_true = type_of_target(y_true, input_name="y_true")
#     110 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/utils/validation.py:464, in check_consistent_length(*arrays)
#     462 lengths = [_num_samples(X) for X in arrays if X is not None]
#     463 if len(set(lengths)) > 1:
# --> 464     raise ValueError(
#     465         "Found input variables with inconsistent numbers of samples: %r"
#     466         % [int(l) for l in lengths]
#     467     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [15216, 3804]

# %%
# KNN
params = {'n_neighbors': [3, 5, 11, 21]}
knn = GridSearchCV(KNeighborsClassifier(), params, cv=5).fit(X_train, y_train_encoded)

# Evaluate
print(f"Accuracy: {knn.best_estimator_.score(X_test, flat_y_test):.4f}")
# Out:
# Accuracy: 0.8465

# %%
# Linear SVM
params = {'C': [0.1, 1, 10]}
l_svm = GridSearchCV(SVC(kernel='linear', probability=True), params, cv=5).fit(X_train, y_train_encoded)

print(f"Accuracy: {l_svm.best_estimator_.score(X_test, flat_y_test):.4f}")
# Out:
# Accuracy: 0.7950

# %%
# Gaussian SVM
params = {'C': [0.1, 1, 10], 'gamma': ['scale', 0.01, 0.1]}
g_svm = GridSearchCV(SVC(kernel='rbf', probability=True), params, cv=5).fit(X_train, y_train_encoded)

print(f"Accuracy: {g_svm.best_estimator_.score(X_test, flat_y_test):.4f}")
# Out:
# Accuracy: 0.8778

# %%
# Random forest
params = {'n_estimators': [50, 100, 200]}
rf = GridSearchCV(RF(), params, cv=5).fit(X_train, y_train_encoded)

best_rf = rf.best_estimator_
print(f"Accuracy: {best_rf.score(X_test, y_test_encoded):.4f}")
print(f"Top Features: {np.argsort(best_rf.feature_importances_)[-3:]}")
# Out:
# Accuracy: 0.8822
# Top Features: [1 0 8]

# %%
# Gradient Boosting
params = {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1]}
gb = GridSearchCV(GBR(), params, cv=5).fit(X_train, y_train_encoded)

best_gb = gb.best_estimator_
print(f"Accuracy: {best_gb.score(X_test, y_test_encoded):.4f}")
print(f"Top Features: {np.argsort(best_gb.feature_importances_)[-3:]}")
# Out:
# Accuracy: 0.8778
# Top Features: [2 0 8]

# %% [markdown]
# ## c. Applying models to test set

# %%
from sklearn.metrics import roc_curve, auc

models = [('LogReg', best_lr), ('LDA', lda), ('KNN', knn.best_estimator_), 
          ('L-SVM', l_svm.best_estimator_), ('G-SVM', g_svm.best_estimator_), 
          ('RF', best_rf), ('GBM', best_gb)]

results = {}
results['AUC'] = []
results['Accuracy'] = []
results['Model'] = []

for name, model in models:
    acc = model.score(X_test, y_test_encoded)
    results['Model'].append(name)
    results['Accuracy'].append(f"{acc:.4f}")

plt.figure(figsize=(8, 6))
for name, model in models:
    probs = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test_encoded, probs)
    results['AUC'].append(f"{auc(fpr, tpr):.4f}")
    plt.plot(fpr, tpr, label=f'{name} (AUC={auc(fpr, tpr):.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.legend(); plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:155, in _check_targets(y_true, y_pred, sample_weight)
#     154 try:
# --> 155     unique_values = _union1d(y_true, y_pred, xp)
#     156 except TypeError as e:
#     157     # We expect y_true and y_pred to be of the same data type.
#     158     # If `y_true` was provided to the classifier as strings,
#     159     # `y_pred` given by the classifier will also be encoded with
#     160     # strings. So we raise a meaningful error
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/utils/_array_api.py:241, in _union1d(a, b, xp)
#     240     a_unique, b_unique = cached_unique(a, b, xp=xp)
# --> 241     return xp.asarray(numpy.union1d(a_unique, b_unique))
#     242 assert a.ndim == b.ndim == 1
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:1113, in union1d(ar1, ar2)
#    1085 """
#    1086 Find the union of two arrays.
#    1087
#    (...)   1111 array([1, 2, 3, 4, 6])
#    1112 """
# -> 1113 return unique(np.concatenate((ar1, ar2), axis=None))
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     295     normalize_axis_index(axis, ar.ndim)
# --> 296 ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                 equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                 sorted=sorted)
#     299 return _unpack_tuple(ret)
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:385, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     384 else:
# --> 385     ar.sort()
#     386     aux = ar
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 13
#      10 results['Model'] = []
#      12 for name, model in models:
# ---> 13     acc = model.score(X_test, y_test_encoded)
#      14     results['Model'].append(name)
#      15     results['Accuracy'].append(f"{acc:.4f}")
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/base.py:566, in ClassifierMixin.score(self, X, y, sample_weight)
#     541 """
#     542 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     543
#    (...)    562     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     563 """
#     564 from sklearn.metrics import accuracy_score
# --> 566 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:411, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     409 # Compute accuracy for each possible representation
#     410 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 411 y_type, y_true, y_pred, sample_weight = _check_targets(
#     412     y_true, y_pred, sample_weight
#     413 )
#     415 if y_type.startswith("multilabel"):
#     416     differing_labels = _count_nonzero(y_true - y_pred, xp=xp, device=device, axis=1)
#
# File ~/miniforge3/envs/ml_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:161, in _check_targets(y_true, y_pred, sample_weight)
#     155     unique_values = _union1d(y_true, y_pred, xp)
#     156 except TypeError as e:
#     157     # We expect y_true and y_pred to be of the same data type.
#     158     # If `y_true` was provided to the classifier as strings,
#     159     # `y_pred` given by the classifier will also be encoded with
#     160     # strings. So we raise a meaningful error
# --> 161     raise TypeError(
#     162         "Labels in y_true and y_pred should be of the same type. "
#     163         f"Got y_true={xp.unique(y_true)} and "
#     164         f"y_pred={xp.unique(y_pred)}. Make sure that the "
#     165         "predictions provided by the classifier coincides with "
#     166         "the true labels."
#     167     ) from e
#     168 if unique_values.shape[0] > 2:
#     169     y_type = "multiclass"
#
# TypeError: Labels in y_true and y_pred should be of the same type. Got y_true=[0 1] and y_pred=['g' 'h']. Make sure that the predictions provided by the classifier coincides with the true labels.
